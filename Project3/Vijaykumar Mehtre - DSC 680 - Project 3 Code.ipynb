# %% [markdown]
# # Project 3
# # Class: DSC 680
# # Name: Vijaykumar Mehtre

# %% [markdown]
# # Load the dataset

# %%
# Load libraries
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load datasets
df = pd.read_csv('Loan_Train.csv')

# %%
# View the df
df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
# 6             2333             1516.0        95.0             360.0
# 7             3036             2504.0       158.0             360.0
# 8             4006             1526.0       168.0             360.0
# 9            12841            10968.0       349.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y
# 5             1.0         Urban           Y
# 6             1.0         Urban           Y
# 7             0.0     Semiurban           N
# 8             1.0         Urban           Y
# 9             1.0     Semiurban           N

# %% [markdown]
# # Data Preparation & Exploration

# %%
# Check for nulls
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# Since any applications with incomplete information will be sent back to the applicant, records containing NAs are to be dropped.

# %%
# Drop records containing na
df = df.dropna()

# %%
# Drop the Loan_ID field
df = df.drop(['Loan_ID'], axis=1)

# %%
# Create dummy variables
df = pd.get_dummies(df)

# %%
# View the dataframe
df.head(5)
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History  Gender_Female  Gender_Male  Married_No  Married_Yes  \
# 1             1.0          False         True       False         True
# 2             1.0          False         True       False         True
# 3             1.0          False         True       False         True
# 4             1.0          False         True        True        False
# 5             1.0          False         True       False         True
#
#    Dependents_0  ...  Dependents_3+  Education_Graduate  \
# 1         False  ...          False                True
# 2          True  ...          False                True
# 3          True  ...          False               False
# 4          True  ...          False                True
# 5         False  ...          False                True
#
#    Education_Not Graduate  Self_Employed_No  Self_Employed_Yes  \
# 1                   False              True              False
# 2                   False             False               True
# 3                    True              True              False
# 4                   False              True              False
# 5                   False             False               True
#
#    Property_Area_Rural  Property_Area_Semiurban  Property_Area_Urban  \
# 1                 True                    False                False
# 2                False                    False                 True
# 3                False                    False                 True
# 4                False                    False                 True
# 5                False                    False                 True
#
#    Loan_Status_N  Loan_Status_Y
# 1           True          False
# 2          False           True
# 3          False           True
# 4          False           True
# 5          False           True
#
# [5 rows x 22 columns]

# %%
# Remove redudant features
df = df.drop(['Gender_Female', 'Married_No', 'Education_Not Graduate', 'Self_Employed_No', 'Loan_Status_N'], axis=1)

# %%
# View the dataframe
df.head(5)
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History  Gender_Male  Married_Yes  Dependents_0  Dependents_1  \
# 1             1.0         True         True         False          True
# 2             1.0         True         True          True         False
# 3             1.0         True         True          True         False
# 4             1.0         True        False          True         False
# 5             1.0         True         True         False         False
#
#    Dependents_2  Dependents_3+  Education_Graduate  Self_Employed_Yes  \
# 1         False          False                True              False
# 2         False          False                True               True
# 3         False          False               False              False
# 4         False          False                True              False
# 5          True          False                True               True
#
#    Property_Area_Rural  Property_Area_Semiurban  Property_Area_Urban  \
# 1                 True                    False                False
# 2                False                    False                 True
# 3                False                    False                 True
# 4                False                    False                 True
# 5                False                    False                 True
#
#    Loan_Status_Y
# 1          False
# 2           True
# 3           True
# 4           True
# 5           True

# %%
# View the correlations
df.corr()
# Out:
#                          ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome                 1.000000          -0.112588    0.495310
# CoapplicantIncome              -0.112588           1.000000    0.190740
# LoanAmount                      0.495310           0.190740    1.000000
# Loan_Amount_Term               -0.010838          -0.005775    0.050867
# Credit_History                 -0.056152          -0.008692   -0.040773
# Gender_Male                     0.032644           0.156171    0.098975
# Married_Yes                     0.036717           0.102950    0.183442
# Dependents_0                   -0.121405           0.000991   -0.178494
# Dependents_1                    0.071367          -0.016015    0.087870
# Dependents_2                   -0.017426           0.028266    0.061174
# Dependents_3+                   0.143633          -0.019006    0.115373
# Education_Graduate              0.131172           0.074499    0.172780
# Self_Employed_Yes               0.170785          -0.001509    0.120389
# Property_Area_Rural             0.045154          -0.001101    0.086569
# Property_Area_Semiurban         0.000551          -0.008322    0.013365
# Property_Area_Urban            -0.044767           0.009866   -0.098826
# Loan_Status_Y                  -0.043152          -0.049020   -0.071753
#
#                          Loan_Amount_Term  Credit_History  Gender_Male  \
# ApplicantIncome                 -0.010838       -0.056152     0.032644
# CoapplicantIncome               -0.005775       -0.008692     0.156171
# LoanAmount                       0.050867       -0.040773     0.098975
# Loan_Amount_Term                 1.000000        0.032937    -0.088704
# Credit_History                   0.032937        1.000000     0.022447
# Gender_Male                     -0.088704        0.022447     1.000000
# Married_Yes                     -0.107504        0.029095     0.349424
# Dependents_0                     0.118518        0.011429    -0.185582
# Dependents_1                    -0.101258       -0.005280    -0.009718
# Dependents_2                    -0.005885        0.037047     0.159802
# Dependents_3+                   -0.066826       -0.063797     0.123341
# Education_Graduate               0.102168        0.056656    -0.059245
# Self_Employed_Yes               -0.034852       -0.023568    -0.002761
# Property_Area_Rural              0.033777       -0.022504     0.058739
# Property_Area_Semiurban          0.030346        0.046480    -0.108538
# Property_Area_Urban             -0.065097       -0.027062     0.057137
# Loan_Status_Y                   -0.007798        0.529390     0.064504
#
#                          Married_Yes  Dependents_0  Dependents_1  \
# ApplicantIncome             0.036717     -0.121405      0.071367
# CoapplicantIncome           0.102950      0.000991     -0.016015
# LoanAmount                  0.183442     -0.178494      0.087870
# Loan_Amount_Term           -0.107504      0.118518     -0.101258
# Credit_History              0.029095      0.011429     -0.005280
# Gender_Male                 0.349424     -0.185582     -0.009718
# Married_Yes                 1.000000     -0.410047      0.154106
# Dependents_0               -0.410047      1.000000     -0.515771
# Dependents_1                0.154106     -0.515771      1.000000
# Dependents_2                0.261974     -0.534999     -0.207456
# Dependents_3+               0.162856     -0.352453     -0.136670
# Education_Graduate         -0.001652      0.014369      0.016242
# Self_Employed_Yes           0.015674     -0.081585      0.081164
# Property_Area_Rural        -0.039048      0.043191     -0.100653
# Property_Area_Semiurban     0.011121      0.034147      0.001903
# Property_Area_Urban         0.026467     -0.078323      0.096484
# Loan_Status_Y               0.112321     -0.022938     -0.040350
#
#                          Dependents_2  Dependents_3+  Education_Graduate  \
# ApplicantIncome             -0.017426       0.143633            0.131172
# CoapplicantIncome            0.028266      -0.019006            0.074499
# LoanAmount                   0.061174       0.115373            0.172780
# Loan_Amount_Term            -0.005885      -0.066826            0.102168
# Credit_History               0.037047      -0.063797            0.056656
# Gender_Male                  0.159802       0.123341           -0.059245
# Married_Yes                  0.261974       0.162856           -0.001652
# Dependents_0                -0.534999      -0.352453            0.014369
# Dependents_1                -0.207456      -0.136670            0.016242
# Dependents_2                 1.000000      -0.141766           -0.011184
# Dependents_3+               -0.141766       1.000000           -0.031827
# Education_Graduate          -0.011184      -0.031827            1.000000
# Self_Employed_Yes            0.036647      -0.013798            0.005085
# Property_Area_Rural         -0.019427       0.084256           -0.067607
# Property_Area_Semiurban     -0.042625      -0.004791            0.038137
# Property_Area_Urban          0.064022      -0.077390            0.025884
# Loan_Status_Y                0.073368      -0.005784            0.068437
#
#                          Self_Employed_Yes  Property_Area_Rural  \
# ApplicantIncome                   0.170785             0.045154
# CoapplicantIncome                -0.001509            -0.001101
# LoanAmount                        0.120389             0.086569
# Loan_Amount_Term                 -0.034852             0.033777
# Credit_History                   -0.023568            -0.022504
# Gender_Male                      -0.002761             0.058739
# Married_Yes                       0.015674            -0.039048
# Dependents_0                     -0.081585             0.043191
# Dependents_1                      0.081164            -0.100653
# Dependents_2                      0.036647            -0.019427
# Dependents_3+                    -0.013798             0.084256
# Education_Graduate                0.005085            -0.067607
# Self_Employed_Yes                 1.000000             0.051851
# Property_Area_Rural               0.051851             1.000000
# Property_Area_Semiurban          -0.015604            -0.519037
# Property_Area_Urban              -0.034261            -0.430446
# Loan_Status_Y                    -0.034715            -0.110817
#
#                          Property_Area_Semiurban  Property_Area_Urban  \
# ApplicantIncome                         0.000551            -0.044767
# CoapplicantIncome                      -0.008322             0.009866
# LoanAmount                              0.013365            -0.098826
# Loan_Amount_Term                        0.030346            -0.065097
# Credit_History                          0.046480            -0.027062
# Gender_Male                            -0.108538             0.057137
# Married_Yes                             0.011121             0.026467
# Dependents_0                            0.034147            -0.078323
# Dependents_1                            0.001903             0.096484
# Dependents_2                           -0.042625             0.064022
# Dependents_3+                          -0.004791            -0.077390
# Education_Graduate                      0.038137             0.025884
# Self_Employed_Yes                      -0.015604            -0.034261
# Property_Area_Rural                    -0.519037            -0.430446
# Property_Area_Semiurban                 1.000000            -0.548096
# Property_Area_Urban                    -0.548096             1.000000
# Loan_Status_Y                           0.155686            -0.055964
#
#                          Loan_Status_Y
# ApplicantIncome              -0.043152
# CoapplicantIncome            -0.049020
# LoanAmount                   -0.071753
# Loan_Amount_Term             -0.007798
# Credit_History                0.529390
# Gender_Male                   0.064504
# Married_Yes                   0.112321
# Dependents_0                 -0.022938
# Dependents_1                 -0.040350
# Dependents_2                  0.073368
# Dependents_3+                -0.005784
# Education_Graduate            0.068437
# Self_Employed_Yes            -0.034715
# Property_Area_Rural          -0.110817
# Property_Area_Semiurban       0.155686
# Property_Area_Urban          -0.055964
# Loan_Status_Y                 1.000000

# %%
# Create a histogram of loan applications
plt.hist(df['LoanAmount'])
plt.title('Loan Applications')
plt.xlabel('Loan Amount in Thousands')
plt.ylabel('Application Count')
# Out:
# Text(0, 0.5, 'Application Count')

# %%
# View the distribution of loan approval
df['Loan_Status_Y'].value_counts()
# Out:
# Loan_Status_Y
# True     332
# False    148
# Name: count, dtype: int64

# %%
# Build training and test datasets
x = df.drop(['Loan_Status_Y'], axis=1)
y = df['Loan_Status_Y']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %% [markdown]
# # Building the model - Logistic Regression

# %%
# Load libraries
from sklearn.linear_model import LogisticRegression

# %%
# Setup an instance of the model
model = LogisticRegression(max_iter=10000)

# %%
# Fit the model
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %% [markdown]
# # Evaluating the model - Logistic Regression

# %%
# Load libraries
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
# Build predictions
predictions = model.predict(x_test)

# %%
# Calculate accuracy score
accuracy_score(y_test, predictions)
# Out:
# 0.7916666666666666

# %%
# Build a confusion matrix of the results
matrix = confusion_matrix(y_test, predictions)

# Create pandas df
cm_df = pd.DataFrame(matrix)

# Create heatmap
ax= plt.subplot()
sns.heatmap(cm_df, annot=True, cbar=None, cmap="Blues", ax=ax)
ax.set_title("Logistic Regression Confusion Matrix")
ax.set_ylabel("True Value"), ax.set_xlabel("Predicted Value")
ax.xaxis.set_ticklabels(['Rejected', 'Approved']); ax.yaxis.set_ticklabels(['Rejected', 'Approved'])
# Out:
# [Text(0, 0.5, 'Rejected'), Text(0, 1.5, 'Approved')]

# %% [markdown]
# The model successfully approved 64 out of 65 loans. However, it incorrectly approved 16/28 loans that should have been rejected.

# %% [markdown]
# # Building the model - Random Forest

# %%
# Load libraries
from sklearn.ensemble import RandomForestClassifier

# %%
# Setup an instance of the model
rf = RandomForestClassifier(n_estimators=10000, random_state=711, n_jobs = -1)

# %%
# Train the model
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10000, n_jobs=-1, random_state=711)

# %% [markdown]
# # Evaluating the model - Random Forest

# %%
# Build predictions
predictions_rf = rf.predict(x_test)

# %%
# Calculate accuracy score
accuracy_score(y_test, predictions_rf)
# Out:
# 0.78125

# %%
# Build a confusion matrix of the results
matrix_rf = confusion_matrix(y_test, predictions_rf)

# Create pandas df
cm_df_rf = pd.DataFrame(matrix_rf)

# Create heatmap
ax= plt.subplot()
sns.heatmap(cm_df_rf, annot=True, cbar=None, cmap="Blues", ax=ax)
ax.set_title("Random Forest Confusion Matrix")
ax.set_ylabel("True Value"), ax.set_xlabel("Predicted Value")
ax.xaxis.set_ticklabels(['Rejected', 'Approved']); ax.yaxis.set_ticklabels(['Rejected', 'Approved'])
# Out:
# [Text(0, 0.5, 'Rejected'), Text(0, 1.5, 'Approved')]

# %% [markdown]
# The random forest model has the same level false positives as the logistic regression model. However, it has a greater number of false negatives.
